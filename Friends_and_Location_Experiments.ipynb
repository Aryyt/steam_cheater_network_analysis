# %% [markdown]
# # Experiments 4 and 5: Homophily Analysis and Geo-social Analyisis

# %% [markdown]
# ### Contents
#
# - [ ] *Experiment 4: Cheater Friend Fraction Analysis*
#   Determine if cheaters have a higher fraction of friends who are cheaters compared to non-cheaters.
#
# - [ ] *Experiment 5.1: Geographic Distribution of Cheaters*
#   Examine the geographical distribution of cheaters to see if it correlates with population density or regional factors.
#
# - [ ] *Experiment 5.2: Node Locality and Geo-Social Metrics*
#   Assess whether cheaters' friendships are geographically closer than those of non-cheaters using node locality metrics.

# %% [markdown]
# ### Start-up
#
# - Import libraries
# - Load the network

# %%
from graph_generation import get_vac_graph_graphml_sample, get_vac_graph_graphml, generate_vac_graph_only_processed, generate_vac_graph_only, ExtractNetwork
import importlib
import HomophilyAnalysis
importlib.reload(HomophilyAnalysis)
from HomophilyAnalysis import HomophilyAnalysis
import networkx as nx
from collections import Counter
import matplotlib.pyplot as plt
import GeoSpatialAnalysis
importlib.reload(GeoSpatialAnalysis)
from GeoSpatialAnalysis import GeoSpatialAnalysis

# %%
# G = get_vac_graph_graphml_sample()

G = ExtractNetwork()
# Out:
# Done

# %% [markdown]
# ## Homophily Analysis

# %%
homophilyAnalysis = HomophilyAnalysis(G, remove_unprocessed = False)
# Out:
# Removing unconnected nodes:

# %%
homophilyAnalysis.density_plot

# %%
homophilyAnalysis.summary
# Out:
#        cheater_proportion  noncheater_proportion
# count         7072.000000           52548.000000
# mean             0.219129               0.096614
# std              0.348145               0.244361
# min              0.000000               0.000000
# 25%              0.000000               0.000000
# 50%              0.000000               0.000000
# 75%              0.333333               0.000000
# max              1.000000               1.000000

# %%
homophilyAnalysis.statistic
# Out:
# 0.1774949694775938

# %%
homophilyAnalysis.p_value
# Out:
# 3.0074998490560344e-172

# %%
homophilyAnalysis.cdf

# %% [markdown]
# ## Geo-Social Analysis

# %%
GSA = GeoSpatialAnalysis(G)

# %%
GSA.plot_freq_all(20)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\crist\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
GSA.plot_freq(20,"Frequency")
# Out:
# C:\Users\crist\PycharmProjects\steam_cheater_network_analysis\GeoSpatialAnalysis.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <module 'matplotlib.pyplot' from 'C:\\Users\\crist\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
GSA.plot_freq(20,"relative_frequency_global")
# Out:
# C:\Users\crist\PycharmProjects\steam_cheater_network_analysis\GeoSpatialAnalysis.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <module 'matplotlib.pyplot' from 'C:\\Users\\crist\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
GSA.plot_freq(20,"relative_frequency_steam_players")
# Out:
# C:\Users\crist\PycharmProjects\steam_cheater_network_analysis\GeoSpatialAnalysis.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <module 'matplotlib.pyplot' from 'C:\\Users\\crist\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
GSA.plot_normalized_populations()

# %% [markdown]
# # Node Locality Analysis (on 75% of the full location data)

# %%
import importlib
import LocalityAnalysis
importlib.reload(LocalityAnalysis)
from LocalityAnalysis import LocalityAnalysis
import genLocData
importlib.reload(genLocData)
from genLocData import gen_loc_data

# %%
#Uncomment IFF locnetData.pkl is missing and run before doing the LocalityAnalysis
# gen_loc_data()

LocalityAnalysis = LocalityAnalysis(generate = True, sample = True)
# Out:
# Done
# Done precomputing node locality
# Done precomputing node locality

# %%
LocalityAnalysis.NLSummary
# Out:
#                       Network  # of Nodes  # of Edges  Avg Dist uv  \
# 0             Steam Community       21669     22015.0  4054.628448
# 1  Steam Community - Cheaters        2654         NaN  4696.145682
# 2          Cheater-to-Cheater        2654       528.0  5119.483541
#
#    Avg link length  Node Locality
# 0      4054.628448       0.801181
# 1              NaN       0.768922
# 2      5119.483541       0.238970

# %%
LocalityAnalysis.cdf_plot

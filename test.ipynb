# %%
import networkx as nx
from pandas import DataFrame
import pickle

# %%
G = nx.DiGraph()
G.add_nodes_from([1, 2])
G.add_edge(1, 2)
G.add_edge(2, 1)

# %%
nx.write_gexf(G, "data/test.gexf")

# %%
with open("data/bloomData.pkl", "rb") as dataPickle:
    data2: DataFrame = pickle.load(dataPickle, fix_imports=True)

# %%
type(data2['ownedGames'].iloc[0])
# Out:
# list

# %%
data2['ownedGames'].iloc[22]
# Out:
# [{'appid': 550,
#   'name': 'Left 4 Dead 2',
#   'playtime_forever': 8,
#   'img_icon_url': '7d5a243f9500d2f8467312822f8af2a2928777ed',
#   'has_community_visible_stats': True,
#   'content_descriptorids': [2, 5]},
#  {'appid': 346110,
#   'name': 'ARK: Survival Evolved',
#   'playtime_forever': 1500,
#   'img_icon_url': 'fef1799533131c10f538d2dd697bbbd89e663265',
#   'has_community_visible_stats': True},
#  {'appid': 407530,
#   'name': 'ARK: Survival Of The Fittest',
#   'playtime_forever': 0,
#   'img_icon_url': '807c673cddebbfee0700a947a75f4872ad136e9b'},
#  {'appid': 219740,
#   'name': "Don't Starve",
#   'playtime_forever': 23,
#   'img_icon_url': '03fe647df40dccc4d19bf42a0185cd3e6b9f2953'},
#  {'appid': 322330,
#   'name': "Don't Starve Together",
#   'playtime_forever': 0,
#   'img_icon_url': 'a80aa6cff8eebc1cbc18c367d9ab063e1553b0ee'},
#  {'appid': 291550,
#   'name': 'Brawlhalla',
#   'playtime_forever': 19,
#   'img_icon_url': 'c43fac31b8bf8821764603a14d09412bc3d45f66',
# ...

# %%
for i in data2['ownedGames'].iloc[22]:
    print(i)
# Out:
# {'appid': 550, 'name': 'Left 4 Dead 2', 'playtime_forever': 8, 'img_icon_url': '7d5a243f9500d2f8467312822f8af2a2928777ed', 'has_community_visible_stats': True, 'content_descriptorids': [2, 5]}
# {'appid': 346110, 'name': 'ARK: Survival Evolved', 'playtime_forever': 1500, 'img_icon_url': 'fef1799533131c10f538d2dd697bbbd89e663265', 'has_community_visible_stats': True}
# {'appid': 407530, 'name': 'ARK: Survival Of The Fittest', 'playtime_forever': 0, 'img_icon_url': '807c673cddebbfee0700a947a75f4872ad136e9b'}
# {'appid': 219740, 'name': "Don't Starve", 'playtime_forever': 23, 'img_icon_url': '03fe647df40dccc4d19bf42a0185cd3e6b9f2953'}
# {'appid': 322330, 'name': "Don't Starve Together", 'playtime_forever': 0, 'img_icon_url': 'a80aa6cff8eebc1cbc18c367d9ab063e1553b0ee'}
# {'appid': 291550, 'name': 'Brawlhalla', 'playtime_forever': 19, 'img_icon_url': 'c43fac31b8bf8821764603a14d09412bc3d45f66', 'has_community_visible_stats': True}
# ...

# %%
G2 = nx.Graph()
G2.add_nodes_from([1,2])
G2.add_edge(1,2)
G2.edges
# Out:
# EdgeView([(1, 2)])

# %%
G2.nodes

# %%
G2.add_node(1)
G2.edges
# Out:
# EdgeView([(1, 2)])

# %%
G2.nodes
